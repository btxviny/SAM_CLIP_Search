# %% [markdown]
# # CLIP + SAM

# %%
import cv2
from segment_anything import build_sam, SamAutomaticMaskGenerator, build_sam_vit_b
from PIL import Image, ImageDraw
import clip
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.cuda.empty_cache()
#mask_generator = SamAutomaticMaskGenerator(build_sam_vit_b(checkpoint="sam_vit_b_01ec64.pth"))
#mask_generator.predictor.model.to('cuda').eval()
mask_generator = SamAutomaticMaskGenerator(build_sam(checkpoint="sam_vit_h_4b8939.pth"))

# %%
# import glob
# import os

# # Define the directory to search in
# directory = './data_from_runs/data_1743688590_329291105/'

# # Use glob to find all 'rgb_image.png' files in the directory (and subdirectories, if needed)
# files = glob.glob(os.path.join(directory, '**', 'rgb_image.png'), recursive=True)

# # Print the paths of the files
# for file in files:
#     print(file)

# %%
image_path = "data_from_runs/data_1743688590_329291105/(1743688590, 391632318)/rgb_image.png"

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
with torch.inference_mode():
    masks = mask_generator.generate(image)

# %%
masks
# Out:
# [{'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 30483,
#   'bbox': [0, 0, 69, 478],
#   'predicted_iou': 1.0158084630966187,
#   'point_coords': [[30.0, 322.5]],
#   'stability_score': 0.9944388270378113,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 50638,
#   'bbox': [61, 315, 476, 163],
#   'predicted_iou': 1.0111273527145386,
#   'point_coords': [[470.0, 442.5]],
#   'stability_score': 0.9682860374450684,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 852,
#   'bbox': [140, 63, 31, 35],
#   'predicted_iou': 1.0077362060546875,
#   'point_coords': [[150.0, 67.5]],
#   'stability_score': 0.9929742217063904,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 8807,
#   'bbox': [153, 0, 288, 59],
#   'predicted_iou': 1.007691502571106,
#   'point_coords': [[270.0, 52.5]],
#   'stability_score': 0.9891635775566101,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1399,
#   'bbox': [329, 97, 36, 44],
#   'predicted_iou': 1.0054017305374146,
#   'point_coords': [[350.0, 112.5]],
#   'stability_score': 0.9850852489471436,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2496,
#   'bbox': [608, 362, 31, 84],
#   'predicted_iou': 1.0014662742614746,
#   'point_coords': [[610.0, 427.5]],
#   'stability_score': 0.9848605394363403,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 629,
#   'bbox': [280, 0, 46, 17],
#   'predicted_iou': 0.99944669008255,
#   'point_coords': [[310.0, 7.5]],
#   'stability_score': 0.9952380657196045,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 546,
#   'bbox': [212, 97, 22, 30],
#   'predicted_iou': 0.9987781643867493,
#   'point_coords': [[230.0, 112.5]],
#   'stability_score': 0.9927272796630859,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3842,
#   'bbox': [563, 0, 76, 81],
#   'predicted_iou': 0.9966819882392883,
#   'point_coords': [[570.0, 7.5]],
#   'stability_score': 0.9896292686462402,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 10380,
#   'bbox': [273, 0, 226, 182],
#   'predicted_iou': 0.9946447014808655,
#   'point_coords': [[310.0, 82.5]],
#   'stability_score': 0.9816653728485107,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1019,
#   'bbox': [86, 102, 30, 41],
#   'predicted_iou': 0.9946191906929016,
#   'point_coords': [[90.0, 127.5]],
#   'stability_score': 0.9883154630661011,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2686,
#   'bbox': [272, 273, 54, 65],
#   'predicted_iou': 0.9941726922988892,
#   'point_coords': [[310.0, 307.5]],
#   'stability_score': 0.9837278127670288,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3638,
#   'bbox': [65, 176, 49, 146],
#   'predicted_iou': 0.993087112903595,
#   'point_coords': [[90.0, 232.5]],
#   'stability_score': 0.958434522151947,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1671,
#   'bbox': [80, 96, 41, 55],
#   'predicted_iou': 0.9923132658004761,
#   'point_coords': [[110.0, 127.5]],
#   'stability_score': 0.9751184582710266,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1496,
#   'bbox': [105, 209, 68, 30],
#   'predicted_iou': 0.9906727075576782,
#   'point_coords': [[110.0, 217.5]],
#   'stability_score': 0.9742574095726013,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 16178,
#   'bbox': [455, 161, 184, 197],
#   'predicted_iou': 0.9883296489715576,
#   'point_coords': [[550.0, 322.5]],
#   'stability_score': 0.9681738018989563,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 288,
#   'bbox': [526, 149, 28, 12],
#   'predicted_iou': 0.9879912734031677,
#   'point_coords': [[530.0, 157.5]],
#   'stability_score': 0.9896551966667175,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1994,
#   'bbox': [256, 58, 17, 126],
#   'predicted_iou': 0.9876423478126526,
#   'point_coords': [[270.0, 97.5]],
#   'stability_score': 0.9845463633537292,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3178,
#   'bbox': [100, 237, 95, 61],
#   'predicted_iou': 0.9865517616271973,
#   'point_coords': [[110.0, 247.5]],
#   'stability_score': 0.975147545337677,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 396,
#   'bbox': [61, 392, 26, 19],
#   'predicted_iou': 0.9853093028068542,
#   'point_coords': [[70.0, 397.5]],
#   'stability_score': 0.9874686598777771,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 6695,
#   'bbox': [525, 198, 114, 80],
#   'predicted_iou': 0.9846368432044983,
#   'point_coords': [[530.0, 247.5]],
#   'stability_score': 0.9592490196228027,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 713,
#   'bbox': [582, 147, 57, 16],
#   'predicted_iou': 0.9846040606498718,
#   'point_coords': [[590.0, 157.5]],
#   'stability_score': 0.9888424277305603,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 5368,
#   'bbox': [164, 281, 87, 101],
#   'predicted_iou': 0.9846036434173584,
#   'point_coords': [[190.0, 337.5]],
#   'stability_score': 0.9804283380508423,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1332,
#   'bbox': [494, 25, 56, 36],
#   'predicted_iou': 0.9840264320373535,
#   'point_coords': [[510.0, 52.5]],
#   'stability_score': 0.9828101396560669,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 14040,
#   'bbox': [0, 0, 40, 478],
#   'predicted_iou': 0.9836364388465881,
#   'point_coords': [[30.0, 217.5]],
#   'stability_score': 0.9529190063476562,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 374,
#   'bbox': [382, 72, 23, 19],
#   'predicted_iou': 0.9822952151298523,
#   'point_coords': [[390.0, 82.5]],
#   'stability_score': 0.9919999837875366,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 993,
#   'bbox': [595, 0, 44, 33],
#   'predicted_iou': 0.9820526838302612,
#   'point_coords': [[610.0, 7.5]],
#   'stability_score': 0.9753694534301758,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 849,
#   'bbox': [63, 239, 15, 80],
#   'predicted_iou': 0.9814419150352478,
#   'point_coords': [[70.0, 277.5]],
#   'stability_score': 0.9882903695106506,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3938,
#   'bbox': [577, 64, 62, 83],
#   'predicted_iou': 0.9805326461791992,
#   'point_coords': [[590.0, 127.5]],
#   'stability_score': 0.9717146158218384,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 6007,
#   'bbox': [499, 336, 77, 95],
#   'predicted_iou': 0.9804472923278809,
#   'point_coords': [[570.0, 382.5]],
#   'stability_score': 0.9756418466567993,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 260,
#   'bbox': [508, 76, 8, 30],
#   'predicted_iou': 0.9787786602973938,
#   'point_coords': [[510.0, 82.5]],
#   'stability_score': 0.9885931611061096,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2768,
#   'bbox': [436, 457, 138, 22],
#   'predicted_iou': 0.9770540595054626,
#   'point_coords': [[570.0, 472.5]],
#   'stability_score': 0.9764873385429382,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 133,
#   'bbox': [151, 74, 11, 13],
#   'predicted_iou': 0.9755446910858154,
#   'point_coords': [[150.0, 82.5]],
#   'stability_score': 0.9776119589805603,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2421,
#   'bbox': [0, 363, 22, 115],
#   'predicted_iou': 0.9750623106956482,
#   'point_coords': [[10.0, 382.5]],
#   'stability_score': 0.9743067026138306,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 629,
#   'bbox': [606, 0, 33, 26],
#   'predicted_iou': 0.9749646782875061,
#   'point_coords': [[610.0, 7.5]],
#   'stability_score': 0.9889415502548218,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 258,
#   'bbox': [498, 0, 36, 10],
#   'predicted_iou': 0.9733389616012573,
#   'point_coords': [[510.0, 7.5]],
#   'stability_score': 0.9884615540504456,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1022,
#   'bbox': [451, 136, 39, 38],
#   'predicted_iou': 0.9733142256736755,
#   'point_coords': [[470.0, 157.5]],
#   'stability_score': 0.9844509363174438,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 439,
#   'bbox': [94, 209, 23, 28],
#   'predicted_iou': 0.973071813583374,
#   'point_coords': [[110.0, 232.5]],
#   'stability_score': 0.9776286482810974,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3762,
#   'bbox': [528, 345, 47, 86],
#   'predicted_iou': 0.9718034267425537,
#   'point_coords': [[530.0, 412.5]],
#   'stability_score': 0.9761092066764832,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 5990,
#   'bbox': [418, 120, 77, 122],
#   'predicted_iou': 0.9714267253875732,
#   'point_coords': [[470.0, 217.5]],
#   'stability_score': 0.9741009473800659,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 3955,
#   'bbox': [417, 157, 74, 85],
#   'predicted_iou': 0.9713766574859619,
#   'point_coords': [[490.0, 217.5]],
#   'stability_score': 0.9638076424598694,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 8960,
#   'bbox': [153, 0, 289, 169],
#   'predicted_iou': 0.9711871147155762,
#   'point_coords': [[250.0, 37.5]],
#   'stability_score': 0.9583378434181213,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 749,
#   'bbox': [109, 259, 27, 34],
#   'predicted_iou': 0.9705278277397156,
#   'point_coords': [[130.0, 277.5]],
#   'stability_score': 0.9867374300956726,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 4778,
#   'bbox': [66, 48, 47, 274],
#   'predicted_iou': 0.9703534841537476,
#   'point_coords': [[70.0, 202.5]],
#   'stability_score': 0.956954300403595,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 674,
#   'bbox': [62, 318, 26, 31],
#   'predicted_iou': 0.9701618552207947,
#   'point_coords': [[70.0, 337.5]],
#   'stability_score': 0.9896449446678162,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 742,
#   'bbox': [61, 343, 29, 35],
#   'predicted_iou': 0.9700047969818115,
#   'point_coords': [[70.0, 352.5]],
#   'stability_score': 0.9826202988624573,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 8595,
#   'bbox': [313, 66, 197, 152],
#   'predicted_iou': 0.9686300754547119,
#   'point_coords': [[370.0, 127.5]],
#   'stability_score': 0.9657370448112488,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 5947,
#   'bbox': [250, 174, 106, 91],
#   'predicted_iou': 0.9680768251419067,
#   'point_coords': [[310.0, 202.5]],
#   'stability_score': 0.968382716178894,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1836,
#   'bbox': [335, 283, 56, 39],
#   'predicted_iou': 0.9677683115005493,
#   'point_coords': [[350.0, 307.5]],
#   'stability_score': 0.9656468033790588,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 347,
#   'bbox': [324, 176, 14, 32],
#   'predicted_iou': 0.9675026535987854,
#   'point_coords': [[330.0, 202.5]],
#   'stability_score': 0.9800570011138916,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 576,
#   'bbox': [69, 45, 26, 32],
#   'predicted_iou': 0.9672818779945374,
#   'point_coords': [[90.0, 67.5]],
#   'stability_score': 0.9828178882598877,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 408,
#   'bbox': [324, 176, 15, 45],
#   'predicted_iou': 0.966610312461853,
#   'point_coords': [[330.0, 202.5]],
#   'stability_score': 0.9830096960067749,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 95,
#   'bbox': [384, 212, 9, 9],
#   'predicted_iou': 0.9665381908416748,
#   'point_coords': [[390.0, 217.5]],
#   'stability_score': 1.0,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 892,
#   'bbox': [448, 120, 47, 36],
#   'predicted_iou': 0.9653278589248657,
#   'point_coords': [[490.0, 127.5]],
#   'stability_score': 0.971270740032196,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1205,
#   'bbox': [335, 283, 32, 39],
#   'predicted_iou': 0.9649114012718201,
#   'point_coords': [[350.0, 292.5]],
#   'stability_score': 0.9697712659835815,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1501,
#   'bbox': [532, 56, 28, 92],
#   'predicted_iou': 0.9648004174232483,
#   'point_coords': [[550.0, 67.5]],
#   'stability_score': 0.9697964787483215,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 8509,
#   'bbox': [313, 3, 185, 214],
#   'predicted_iou': 0.9643121361732483,
#   'point_coords': [[390.0, 187.5]],
#   'stability_score': 0.958476722240448,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2614,
#   'bbox': [100, 236, 94, 39],
#   'predicted_iou': 0.9636660218238831,
#   'point_coords': [[150.0, 247.5]],
#   'stability_score': 0.9706214666366577,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 5289,
#   'bbox': [164, 280, 147, 87],
#   'predicted_iou': 0.9634503126144409,
#   'point_coords': [[170.0, 337.5]],
#   'stability_score': 0.9720566272735596,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1318,
#   'bbox': [582, 147, 57, 51],
#   'predicted_iou': 0.9625639915466309,
#   'point_coords': [[590.0, 157.5]],
#   'stability_score': 0.9605947732925415,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 30454,
#   'bbox': [0, 0, 256, 478],
#   'predicted_iou': 0.962078332901001,
#   'point_coords': [[50.0, 457.5]],
#   'stability_score': 0.9613569378852844,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True]], shape=(480, 640)),
#   'area': 515,
#   'bbox': [624, 447, 15, 32],
#   'predicted_iou': 0.9619982838630676,
#   'point_coords': [[630.0, 457.5]],
#   'stability_score': 0.9845559597015381,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 137,
#   'bbox': [220, 151, 12, 11],
#   'predicted_iou': 0.9615254402160645,
#   'point_coords': [[230.0, 157.5]],
#   'stability_score': 0.9856114983558655,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 369,
#   'bbox': [315, 238, 26, 17],
#   'predicted_iou': 0.9612504839897156,
#   'point_coords': [[330.0, 247.5]],
#   'stability_score': 0.9892183542251587,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 128,
#   'bbox': [221, 166, 12, 11],
#   'predicted_iou': 0.9607007503509521,
#   'point_coords': [[230.0, 172.5]],
#   'stability_score': 0.9922480583190918,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 4762,
#   'bbox': [501, 160, 138, 144],
#   'predicted_iou': 0.9604677557945251,
#   'point_coords': [[530.0, 202.5]],
#   'stability_score': 0.9561025500297546,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 8401,
#   'bbox': [313, 66, 133, 150],
#   'predicted_iou': 0.9597421288490295,
#   'point_coords': [[330.0, 172.5]],
#   'stability_score': 0.9637275338172913,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 132,
#   'bbox': [223, 133, 9, 15],
#   'predicted_iou': 0.9596606492996216,
#   'point_coords': [[230.0, 142.5]],
#   'stability_score': 0.9624060392379761,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 250,
#   'bbox': [123, 60, 13, 21],
#   'predicted_iou': 0.9595391154289246,
#   'point_coords': [[130.0, 67.5]],
#   'stability_score': 0.9610894918441772,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 160,
#   'bbox': [405, 329, 11, 16],
#   'predicted_iou': 0.9591269493103027,
#   'point_coords': [[410.0, 337.5]],
#   'stability_score': 0.987500011920929,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 665,
#   'bbox': [526, 149, 28, 28],
#   'predicted_iou': 0.9582322835922241,
#   'point_coords': [[530.0, 172.5]],
#   'stability_score': 0.9734120965003967,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 150,
#   'bbox': [626, 48, 11, 15],
#   'predicted_iou': 0.9572394490242004,
#   'point_coords': [[630.0, 52.5]],
#   'stability_score': 1.0,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 198,
#   'bbox': [150, 132, 15, 14],
#   'predicted_iou': 0.9568716287612915,
#   'point_coords': [[150.0, 142.5]],
#   'stability_score': 0.9800000190734863,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 208,
#   'bbox': [396, 179, 14, 16],
#   'predicted_iou': 0.9566453695297241,
#   'point_coords': [[410.0, 187.5]],
#   'stability_score': 0.9855769276618958,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 871,
#   'bbox': [428, 235, 28, 36],
#   'predicted_iou': 0.9545658230781555,
#   'point_coords': [[430.0, 247.5]],
#   'stability_score': 0.9727582335472107,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 4701,
#   'bbox': [87, 293, 86, 74],
#   'predicted_iou': 0.9540244936943054,
#   'point_coords': [[150.0, 307.5]],
#   'stability_score': 0.9702742099761963,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1232,
#   'bbox': [491, 198, 30, 73],
#   'predicted_iou': 0.953775942325592,
#   'point_coords': [[510.0, 217.5]],
#   'stability_score': 0.9569377899169922,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 228,
#   'bbox': [131, 85, 12, 19],
#   'predicted_iou': 0.953460156917572,
#   'point_coords': [[130.0, 97.5]],
#   'stability_score': 0.9956331849098206,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 11625,
#   'bbox': [454, 269, 185, 91],
#   'predicted_iou': 0.9520866870880127,
#   'point_coords': [[530.0, 277.5]],
#   'stability_score': 0.9547331929206848,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 380,
#   'bbox': [527, 159, 24, 19],
#   'predicted_iou': 0.9501331448554993,
#   'point_coords': [[530.0, 172.5]],
#   'stability_score': 0.9765625,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 291,
#   'bbox': [231, 230, 33, 12],
#   'predicted_iou': 0.9496578574180603,
#   'point_coords': [[250.0, 232.5]],
#   'stability_score': 0.9661017060279846,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
# ...
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 98,
#   'bbox': [305, 231, 14, 9],
#   'predicted_iou': 0.9082054495811462,
#   'point_coords': [[310.0, 232.5]],
#   'stability_score': 0.9797979593276978,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1885,
#   'bbox': [448, 120, 47, 54],
#   'predicted_iou': 0.9071213006973267,
#   'point_coords': [[470.0, 157.5]],
#   'stability_score': 0.972294807434082,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 146,
#   'bbox': [0, 363, 18, 12],
#   'predicted_iou': 0.9069462418556213,
#   'point_coords': [[10.0, 367.5]],
#   'stability_score': 0.9731543660163879,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 214,
#   'bbox': [449, 57, 14, 16],
#   'predicted_iou': 0.906718909740448,
#   'point_coords': [[450.0, 67.5]],
#   'stability_score': 0.9543378949165344,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 2609,
#   'bbox': [454, 273, 57, 63],
#   'predicted_iou': 0.9065511226654053,
#   'point_coords': [[490.0, 322.5]],
#   'stability_score': 0.9758033752441406,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 211,
#   'bbox': [128, 141, 18, 13],
#   'predicted_iou': 0.9064652323722839,
#   'point_coords': [[130.0, 142.5]],
#   'stability_score': 0.9627906680107117,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1988,
#   'bbox': [382, 53, 81, 38],
#   'predicted_iou': 0.9056072235107422,
#   'point_coords': [[390.0, 82.5]],
#   'stability_score': 0.9581074714660645,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 129,
#   'bbox': [566, 79, 10, 16],
#   'predicted_iou': 0.9053859114646912,
#   'point_coords': [[570.0, 82.5]],
#   'stability_score': 0.9769230484962463,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 527,
#   'bbox': [416, 298, 37, 16],
#   'predicted_iou': 0.9049125909805298,
#   'point_coords': [[430.0, 307.5]],
#   'stability_score': 0.9611830115318298,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 372,
#   'bbox': [598, 108, 31, 39],
#   'predicted_iou': 0.902933657169342,
#   'point_coords': [[610.0, 127.5]],
#   'stability_score': 0.9605262875556946,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 366,
#   'bbox': [175, 74, 16, 28],
#   'predicted_iou': 0.900240421295166,
#   'point_coords': [[190.0, 97.5]],
#   'stability_score': 0.9651474356651306,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 566,
#   'bbox': [123, 44, 20, 37],
#   'predicted_iou': 0.8988207578659058,
#   'point_coords': [[130.0, 67.5]],
#   'stability_score': 0.9547826051712036,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 230,
#   'bbox': [153, 119, 17, 15],
#   'predicted_iou': 0.8936194181442261,
#   'point_coords': [[170.0, 127.5]],
#   'stability_score': 0.9661017060279846,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 210,
#   'bbox': [485, 85, 7, 27],
#   'predicted_iou': 0.8935158252716064,
#   'point_coords': [[490.0, 97.5]],
#   'stability_score': 0.9904761910438538,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 94,
#   'bbox': [525, 177, 12, 14],
#   'predicted_iou': 0.8928378224372864,
#   'point_coords': [[530.0, 187.5]],
#   'stability_score': 0.9583333134651184,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 245,
#   'bbox': [126, 122, 18, 16],
#   'predicted_iou': 0.8915419578552246,
#   'point_coords': [[130.0, 127.5]],
#   'stability_score': 0.975806474685669,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 221,
#   'bbox': [375, 263, 14, 21],
#   'predicted_iou': 0.8913154006004333,
#   'point_coords': [[390.0, 277.5]],
#   'stability_score': 0.9559471607208252,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 201,
#   'bbox': [131, 108, 18, 15],
#   'predicted_iou': 0.8890588879585266,
#   'point_coords': [[130.0, 112.5]],
#   'stability_score': 0.9704433679580688,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 243,
#   'bbox': [164, 317, 16, 18],
#   'predicted_iou': 0.8885844945907593,
#   'point_coords': [[170.0, 322.5]],
#   'stability_score': 0.9638554453849792,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 143,
#   'bbox': [209, 131, 12, 13],
#   'predicted_iou': 0.8883358240127563,
#   'point_coords': [[210.0, 142.5]],
#   'stability_score': 0.9520547986030579,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1406,
#   'bbox': [61, 318, 29, 60],
#   'predicted_iou': 0.8880093097686768,
#   'point_coords': [[70.0, 337.5]],
#   'stability_score': 0.9698668718338013,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 4706,
#   'bbox': [86, 293, 152, 74],
#   'predicted_iou': 0.8874189853668213,
#   'point_coords': [[90.0, 337.5]],
#   'stability_score': 0.970815122127533,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 424,
#   'bbox': [420, 93, 13, 32],
#   'predicted_iou': 0.8871545791625977,
#   'point_coords': [[430.0, 112.5]],
#   'stability_score': 0.9813084006309509,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 356,
#   'bbox': [389, 195, 26, 17],
#   'predicted_iou': 0.8862758874893188,
#   'point_coords': [[390.0, 202.5]],
#   'stability_score': 0.9615384340286255,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 253,
#   'bbox': [467, 229, 27, 11],
#   'predicted_iou': 0.8860072493553162,
#   'point_coords': [[490.0, 232.5]],
#   'stability_score': 0.96138995885849,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 87,
#   'bbox': [150, 152, 8, 10],
#   'predicted_iou': 0.8842349648475647,
#   'point_coords': [[150.0, 157.5]],
#   'stability_score': 0.9772727489471436,
#   'crop_box': [0, 0, 640, 480]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ...,  True,  True,  True],
#          [False, False, False, ..., False, False, False]], shape=(480, 640)),
#   'area': 1067,
#   'bbox': [608, 443, 31, 35],
#   'predicted_iou': 0.8808262944221497,
#   'point_coords': [[610.0, 457.5]],
#   'stability_score': 0.9823583960533142,
#   'crop_box': [0, 0, 640, 480]}]

# %%
def convert_box_xywh_to_xyxy(box):
    x1 = box[0]
    y1 = box[1]
    x2 = box[0] + box[2]
    y2 = box[1] + box[3]
    return [x1, y1, x2, y2]

# %%
def segment_image(image, segmentation_mask):
    image_array = np.array(image)
    segmented_image_array = np.zeros_like(image_array)
    segmented_image_array[segmentation_mask] = image_array[segmentation_mask]
    segmented_image = Image.fromarray(segmented_image_array)
    black_image = Image.new("RGB", image.size, (0, 0, 0))
    transparency_mask = np.zeros_like(segmentation_mask, dtype=np.uint8)
    transparency_mask[segmentation_mask] = 255
    transparency_mask_image = Image.fromarray(transparency_mask, mode='L')
    black_image.paste(segmented_image, mask=transparency_mask_image)
    return black_image

# %%
# Cut out all masks
image = Image.open(image_path)
cropped_boxes = []

for mask in masks:
    cropped_boxes.append(segment_image(image, mask["segmentation"]).crop(convert_box_xywh_to_xyxy(mask["bbox"])))

# %%
# Load CLIP
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model, preprocess = clip.load("ViT-B/32", device=device)

# %%
@torch.no_grad()
def retriev(elements: list[Image.Image], search_text: str) -> int:
    preprocessed_images = [preprocess(image).to(device) for image in elements]
    tokenized_text = clip.tokenize([search_text]).to(device)
    stacked_images = torch.stack(preprocessed_images)
    image_features = model.encode_image(stacked_images)
    text_features = model.encode_text(tokenized_text)
    image_features /= image_features.norm(dim=-1, keepdim=True)
    text_features /= text_features.norm(dim=-1, keepdim=True)
    probs = 100. * image_features @ text_features.T
    return probs[:, 0].softmax(dim=0)

# %%
def get_indices_of_values_above_threshold(values, threshold):
    return [i for i, v in enumerate(values) if v > threshold]

# %%
scores = retriev(cropped_boxes, "chair")
indices = get_indices_of_values_above_threshold(scores, 0.05)

segmentation_masks = []

for seg_idx in indices:
    segmentation_mask_image = Image.fromarray(masks[seg_idx]["segmentation"].astype('uint8') * 255)
    segmentation_masks.append(segmentation_mask_image)

original_image = Image.open(image_path)
overlay_image = Image.new('RGBA', image.size, (0, 0, 0, 0))
overlay_color = (255, 0, 0, 100)

draw = ImageDraw.Draw(overlay_image)
for segmentation_mask_image in segmentation_masks:
    draw.bitmap((0, 0), segmentation_mask_image, fill=overlay_color)

result_image = Image.alpha_composite(original_image.convert('RGBA'), overlay_image)
result_image
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
scores = retriev(cropped_boxes, "bookcase")
print(scores.shape)
indices = get_indices_of_values_above_threshold(scores, 0.05)

segmentation_masks = []

for seg_idx in indices:
    segmentation_mask_image = Image.fromarray(masks[seg_idx]["segmentation"].astype('uint8') * 255)
    segmentation_masks.append(segmentation_mask_image)

original_image = Image.open(image_path)
overlay_image = Image.new('RGBA', image.size, (0, 0, 0, 0))
overlay_color = (255, 0, 0, 100)

draw = ImageDraw.Draw(overlay_image)
for segmentation_mask_image in segmentation_masks:
    draw.bitmap((0, 0), segmentation_mask_image, fill=overlay_color)

result_image = Image.alpha_composite(original_image.convert('RGBA'), overlay_image)
result_image
# Out:
# torch.Size([162])
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
scores = retriev(cropped_boxes, "plant")
indices = get_indices_of_values_above_threshold(scores, 0.05)

segmentation_masks = []

for seg_idx in indices:
    segmentation_mask_image = Image.fromarray(masks[seg_idx]["segmentation"].astype('uint8') * 255)
    segmentation_masks.append(segmentation_mask_image)

original_image = Image.open(image_path)
overlay_image = Image.new('RGBA', image.size, (0, 0, 0, 0))
overlay_color = (255, 0, 0, 100)

draw = ImageDraw.Draw(overlay_image)
for segmentation_mask_image in segmentation_masks:
    draw.bitmap((0, 0), segmentation_mask_image, fill=overlay_color)

result_image = Image.alpha_composite(original_image.convert('RGBA'), overlay_image)
result_image
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>
